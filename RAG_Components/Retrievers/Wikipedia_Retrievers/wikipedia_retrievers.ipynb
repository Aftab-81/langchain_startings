# %%
from langchain_community.retrievers.wikipedia import WikipediaRetriever

# %%
retriever = WikipediaRetriever(top_k_results = 5,
 lang = 'en',
 doc_content_chars_max = 100)

# %%
query = "Battle through the heavens"

# %%
docs = retriever.invoke(query)

# %%
docs
# Out:
# [Document(metadata={'title': 'Battle Through the Heavens', 'summary': "Battle Through the Heavens (Chinese: 斗破苍穹; pinyin: Dòupò Cāngqióng; lit. 'Fight Through The Sky') is a 2018 Chinese television series adapted from the eponymous web novel Doupo Cangqiong (斗破苍穹) by Tiancan Tudou (天蚕土豆). It stars Leo Wu, Lin Yun, Li Qin, Baron Chen, Xin Zhilei and Liu Meitong.  The series aired on Hunan TV on September 3, 2018 till October 25, 2018.", 'source': 'https://en.wikipedia.org/wiki/Battle_Through_the_Heavens'}, page_content="Battle Through the Heavens (Chinese: 斗破苍穹; pinyin: Dòupò Cāngqióng; lit. 'Fight Through The Sky') is"),
#  Document(metadata={'title': 'Lin Yun', 'summary': 'Lin Yun (Chinese: 林允; pinyin: Lín Yǔn, born April 16, 1996), also known by her English name Jelly Lin, is a Chinese actress and model. She is best known for her role as the female lead in the 2016 film The Mermaid.', 'source': 'https://en.wikipedia.org/wiki/Lin_Yun'}, page_content='Lin Yun (Chinese: 林允; pinyin: Lín Yǔn, born April 16, 1996), also known by her English name Jelly Li'),
#  Document(metadata={'title': 'Su Qing (actress)', 'summary': "Su Qing (Chinese: 苏青, born 5 July 1989) is a Chinese actress known for her roles as Zhang Yan in Beauty's Rival in Palace and the antagonist Hitara Erqing in Story of Yanxi Palace.", 'source': 'https://en.wikipedia.org/wiki/Su_Qing_(actress)'}, page_content='Su Qing (Chinese: 苏青, born 5 July 1989) is a Chinese actress known for her roles as Zhang Yan in Bea'),
#  Document(metadata={'title': 'List of Chinese television series', 'summary': 'This is a list of Chinese television series by genre. For a chronological list, see List of Chinese television programs by date.\n\n', 'source': 'https://en.wikipedia.org/wiki/List_of_Chinese_television_series'}, page_content='This is a list of Chinese television series by genre. For a chronological list, see List of Chinese '),
#  Document(metadata={'title': 'List of Chinese animated series', 'summary': 'This is a list of Chinese animated TV shows sorted by year. They are in Mandarin Chinese language only:', 'source': 'https://en.wikipedia.org/wiki/List_of_Chinese_animated_series'}, page_content='This is a list of Chinese animated TV shows sorted by year. They are in Mandarin Chinese language on')]

# %%
for i, doc in enumerate(docs, start = 1):
    print(f"Document: {i}")
    print(doc)
# Out:
# Document: 1
# page_content='Battle Through the Heavens (Chinese: 斗破苍穹; pinyin: Dòupò Cāngqióng; lit. 'Fight Through The Sky') is' metadata={'title': 'Battle Through the Heavens', 'summary': "Battle Through the Heavens (Chinese: 斗破苍穹; pinyin: Dòupò Cāngqióng; lit. 'Fight Through The Sky') is a 2018 Chinese television series adapted from the eponymous web novel Doupo Cangqiong (斗破苍穹) by Tiancan Tudou (天蚕土豆). It stars Leo Wu, Lin Yun, Li Qin, Baron Chen, Xin Zhilei and Liu Meitong.  The series aired on Hunan TV on September 3, 2018 till October 25, 2018.", 'source': 'https://en.wikipedia.org/wiki/Battle_Through_the_Heavens'}
# Document: 2
# page_content='Lin Yun (Chinese: 林允; pinyin: Lín Yǔn, born April 16, 1996), also known by her English name Jelly Li' metadata={'title': 'Lin Yun', 'summary': 'Lin Yun (Chinese: 林允; pinyin: Lín Yǔn, born April 16, 1996), also known by her English name Jelly Lin, is a Chinese actress and model. She is best known for her role as the female lead in the 2016 film The Mermaid.', 'source': 'https://en.wikipedia.org/wiki/Lin_Yun'}
# Document: 3
# page_content='Su Qing (Chinese: 苏青, born 5 July 1989) is a Chinese actress known for her roles as Zhang Yan in Bea' metadata={'title': 'Su Qing (actress)', 'summary': "Su Qing (Chinese: 苏青, born 5 July 1989) is a Chinese actress known for her roles as Zhang Yan in Beauty's Rival in Palace and the antagonist Hitara Erqing in Story of Yanxi Palace.", 'source': 'https://en.wikipedia.org/wiki/Su_Qing_(actress)'}
# Document: 4
# page_content='This is a list of Chinese television series by genre. For a chronological list, see List of Chinese ' metadata={'title': 'List of Chinese television series', 'summary': 'This is a list of Chinese television series by genre. For a chronological list, see List of Chinese television programs by date.\n\n', 'source': 'https://en.wikipedia.org/wiki/List_of_Chinese_television_series'}
# Document: 5
# page_content='This is a list of Chinese animated TV shows sorted by year. They are in Mandarin Chinese language on' metadata={'title': 'List of Chinese animated series', 'summary': 'This is a list of Chinese animated TV shows sorted by year. They are in Mandarin Chinese language only:', 'source': 'https://en.wikipedia.org/wiki/List_of_Chinese_animated_series'}
